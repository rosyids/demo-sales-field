# %%
import pandas as pd
df = pd.read_excel('data/input/Field Sales_template (3) BWI001.xlsx')

# %%
df
# Out:
#           Cutomer Name                                   Customer Address  \
# 0      CWRK009-00-0155  JL DR SUTOMO 27 Banyuwangi Kab. Banyuwangi Jaw...
# 1      CWRK009-00-0033  DALAM PASAR NO 61 Banyuwangi Kab. Banyuwangi J...
# 2      CWRK009-00-0034  JL A YANI NO 10 Banyuwangi Kab. Banyuwangi Jaw...
# 3      CWRK009-00-0421  JL. A YANI PENGAJUARAN BLOCK NO 21-23 Banyuwan...
# 4      CWRK009-00-0010  JL SAYUWIWIT 38 Banyuwangi Kab. Banyuwangi Jaw...
# ..                 ...                                                ...
# 312    CWRK009-00-0700  PEREMPATAN PASAR SRATEN Cluring Kab. Banyuwang...
# 313  WRK009-21-0000053  JL RAYA JEMBER GLENMORE Glenmore Kab. Banyuwan...
# 314  WRK009-23-0000034  DS KARANGREJO NO 3 GLENMORE Glenmore Kab. Bany...
# 315  WRK009-21-0000032  KEMIREN BANYUWANGI Licin Kab. Banyuwangi Jawa ...
# 316  WRK009-23-0000031  JL RAYA IJEN KRAJAN KEC LICIN  BANYUWANGI  Lic...
#
#                        Customer Coordinate Open Time Close Time  Visit Tag  \
# ...

# %%
# Daftar Customer Name yang ingin diatur
customer_names = [
    'CWRK009-00-0155', 'CWRK009-00-0022', 'WRK009-23-0000141',
    'CWRK009-00-0360', 'WRK009-19-0000009', 'WRK009-21-0000082',
    'CWRK009-00-0217', 'CWRK009-00-0238', 'CWRK009-00-0278',
    'CWRK009-00-0402', 'WRK009-20-0000063', 'WRK009-20-0000063',
    'WRK009-20-0000063', 'WRK009-20-0000063', 'WRK009-20-0000063',
    'WRK009-20-0000063', 'WRK009-23-0000104', 'WRK009-23-0000104',
    'CWRK009-00-0930', 'CWRK009-00-0867', 'CWRK009-00-0476',
    'CWRK009-00-0300', 'CWRK009-00-0326', 'CWRK009-00-0225',
    'CWRK009-00-0105', 'WRK009-21-0000096', 'WRK009-21-0000058',
    'CWRK009-00-0184'
]

# Filter data berdasarkan Customer Name
filtered_df = df[df['Cutomer Name'].isin(customer_names)]

# Menggunakan iloc untuk menyusun data
filtered_df_w1v1 = filtered_df.copy()
filtered_df_w1v1.set_index('Cutomer Name', inplace=True)
filtered_df_w1v1 = filtered_df_w1v1.loc[customer_names].reset_index()

# %%
filtered_df_w1v1
# Out:
#          Cutomer Name                                   Customer Address  \
# 0     CWRK009-00-0155  JL DR SUTOMO 27 Banyuwangi Kab. Banyuwangi Jaw...
# 1     CWRK009-00-0022  JL MH THAMRIN 26 Banyuwangi Kab. Banyuwangi Ja...
# 2   WRK009-23-0000141  PAKIS BANYUWANGI Banyuwangi Kab. Banyuwangi Ja...
# 3     CWRK009-00-0360     TEMBOK REJO  Muncar Kab. Banyuwangi Jawa Timur
# 4   WRK009-19-0000009  JL RAYA SETINGGIL NO 35 MUNCAR Muncar Kab. Ban...
# 5   WRK009-21-0000082  JL BRAWIJAYA MUNCAR Muncar Kab. Banyuwangi Jaw...
# 6     CWRK009-00-0217       JL PATEMON Muncar Kab. Banyuwangi Jawa Timur
# 7     CWRK009-00-0238  JL SETINGGIL 35 Muncar Kab. Banyuwangi Jawa Timur
# 8     CWRK009-00-0278  JL RAYA SUMBER AYU Muncar Kab. Banyuwangi Jawa...
# 9     CWRK009-00-0402  JL RAYA SUMBER AYU Muncar Kab. Banyuwangi Jawa...
# 10  WRK009-20-0000063  KALIPAIT DAM BUNTUNG BANYUWANGI Tegaldlimo Kab...
# 11  WRK009-20-0000063  KALIPAIT DAM BUNTUNG BANYUWANGI Tegaldlimo Kab...
# ...

# %%
# Daftar Customer Name yang ingin diatur
customer_names = [
    'CWRK009-00-0044', 'WRK009-21-0000007', 'CWRK009-00-0064',
    'WRK009-22-0000002', 'WRK009-22-0000002', 'CWRK009-00-0023',
    'WRK009-21-0000103', 'CWRK009-00-0193', 'CWRK009-00-0033',
    'WRK009-23-0000129', 'WRK009-19-0000018', 'CWRK009-00-0081'
]

# Filter data berdasarkan Customer Name
filtered_df = df[df['Cutomer Name'].isin(customer_names)]

# Menggunakan iloc untuk menyusun data
df_w1v2 = filtered_df.copy()
df_w1v2.set_index('Cutomer Name', inplace=True)
df_w1v2 = df_w1v2.loc[customer_names].reset_index()
# Menyimpan hasil ke file baru
df_w1v2.to_excel('data\output\Filtered_df_w1v2.xlsx', index=False)
# Out:
# <>:17: SyntaxWarning: invalid escape sequence '\o'
# <>:17: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\muham\AppData\Local\Temp\ipykernel_10252\1964984590.py:17: SyntaxWarning: invalid escape sequence '\o'
#   df_w1v2.to_excel('data\output\Filtered_df_w1v2.xlsx', index=False)

# %%
df_w1v2
# Out:
#          Cutomer Name                                   Customer Address  \
# 0     CWRK009-00-0044  JL MH THAMRIN 35 Banyuwangi Kab. Banyuwangi Ja...
# 1   WRK009-21-0000007  UTARA TERMINAL BLAMBANGAN BANYUWANGI Banyuwang...
# 2     CWRK009-00-0064  JL BASUKI RAHMAT 170 Banyuwangi Kab. Banyuwang...
# 3   WRK009-22-0000002  WONGSOREJO BANYUWANGI Wongsorejo Kab. Banyuwan...
# 4   WRK009-22-0000002  WONGSOREJO BANYUWANGI Wongsorejo Kab. Banyuwan...
# 5     CWRK009-00-0023  JL RAYA SITUBONDO  Wongsorejo Kab. Banyuwangi ...
# 6   WRK009-21-0000103  JL TIRTOPURO KALIPURO Kalipuro Kab. Banyuwangi...
# 7     CWRK009-00-0193  BRAK KALIPURO Kalipuro Kab. Banyuwangi Jawa Timur
# 8     CWRK009-00-0033  DALAM PASAR NO 61 Banyuwangi Kab. Banyuwangi J...
# 9   WRK009-23-0000129  TAMAN BLAMBANGAN BANYUWANGI Banyuwangi Kab. Ba...
# 10  WRK009-19-0000018  PULAU SANTEN KARANGREJO BANYUWANGI Banyuwangi ...
# 11    CWRK009-00-0081  JL KAPT P TENDEAN 7 Banyuwangi Kab. Banyuwangi...
#
# ...

# %%
# Daftar Customer Name yang ingin diatur
customer_names = [
    'WRK009-23-0000092', 'WRK009-23-0000145', 'WRK009-21-0000064',
    'WRK009-22-0000007', 'WRK009-22-0000029', 'WRK009-22-0000013',
    'CWRK009-00-0109', 'CWRK009-00-0866', 'CWRK009-00-0517',
    'CWRK009-00-0031', 'WRK009-21-0000100', 'CWRK009-00-0014',
    'CWRK009-00-0700', 'CWRK009-00-0127', 'CWRK009-00-0018',
    'WRK009-23-0000059', 'WRK009-19-0000003', 'WRK009-20-0000052'
]


# Filter data berdasarkan Customer Name
filtered_df = df[df['Cutomer Name'].isin(customer_names)]

# Menggunakan iloc untuk menyusun data
df_w1v3 = filtered_df.copy()
df_w1v3.set_index('Cutomer Name', inplace=True)
df_w1v3 = df_w1v3.loc[customer_names].reset_index()
# Menyimpan hasil ke file baru
df_w1v3.to_excel('data\output\Filtered_df_w1v3.xlsx', index=False)
# Out:
# <>:20: SyntaxWarning: invalid escape sequence '\o'
# <>:20: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\muham\AppData\Local\Temp\ipykernel_10252\1313911661.py:20: SyntaxWarning: invalid escape sequence '\o'
#   df_w1v3.to_excel('data\output\Filtered_df_w1v3.xlsx', index=False)

# %%
df_w1v3
# Out:
#          Cutomer Name                                   Customer Address  \
# 0   WRK009-23-0000092  JL MENDUT 24 BANYUWANGI Banyuwangi Kab. Banyuw...
# 1   WRK009-23-0000145  JL ADI SUCIPTO BANYUWANGI Banyuwangi Kab. Bany...
# 2   WRK009-21-0000064  JL RAYA CLURING DN KEPATIHAN  BANYUWANGI Cluri...
# 3   WRK009-22-0000007  JL SUTAWIJAYA PAKIS KRAJAN BANYUWANGI Glagah K...
# 4   WRK009-22-0000029  JL ARUJI KERTAWINATA DSN JURUH Singojuruh Kab....
# 5   WRK009-22-0000013            GENDOH Sempu Kab. Banyuwangi Jawa Timur
# 6     CWRK009-00-0109  JL RAYA GENDOH 144  Singojuruh Kab. Banyuwangi...
# 7     CWRK009-00-0866  Jl. KH. Wahid Hasyim No. 149 Genteng Kab. Bany...
# 8     CWRK009-00-0517  JL RAYA TEGALSARI Genteng Kab. Banyuwangi Jawa...
# 9     CWRK009-00-0031  JL HASNUDIN 134 Genteng Kab. Banyuwangi Jawa T...
# 10  WRK009-21-0000100  JL RAYA GEMBIRITAN GENTENG Genteng Kab. Banyuw...
# 11    CWRK009-00-0014  JL S PARMAN 106A Banyuwangi Kab. Banyuwangi Ja...
# ...

# %%
# Daftar Customer Name yang ingin diatur
customer_names = [
    'CWRK009-00-0926', 'CWRK009-00-0188', 'CWRK009-00-0765', 'CWRK009-00-0258',
    'CWRK009-00-0055', 'WRK009-23-0000144', 'WRK009-23-0000144', 'WRK009-22-0000025',
    'WRK009-21-0000020', 'WRK009-21-0000020', 'WRK009-21-0000020', 'CWRK009-00-0801',
    'CWRK009-00-0801', 'CWRK009-00-0801', 'CWRK009-00-0801', 'CWRK009-00-0478',
    'WRK009-21-0000053', 'WRK009-21-0000043', 'WRK009-21-0000043', 'WRK009-21-0000043',
    'CWRK009-00-0414', 'CWRK009-00-0414', 'CWRK009-00-0174', 'WRK009-23-0000139',
    'WRK009-23-0000139'
]



# Filter data berdasarkan Customer Name
filtered_df = df[df['Cutomer Name'].isin(customer_names)]

# Menggunakan iloc untuk menyusun data
df_w1v4 = filtered_df.copy()
df_w1v4.set_index('Cutomer Name', inplace=True)
df_w1v4 = df_w1v4.loc[customer_names].reset_index()
# Menyimpan hasil ke file baru
df_w1v4.to_excel('data\output\Filtered_df_w1v4.xlsx', index=False)
# Out:
# <>:22: SyntaxWarning: invalid escape sequence '\o'
# <>:22: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\muham\AppData\Local\Temp\ipykernel_10252\3443083419.py:22: SyntaxWarning: invalid escape sequence '\o'
#   df_w1v4.to_excel('data\output\Filtered_df_w1v4.xlsx', index=False)

# %%
df_w1v4
# Out:
#          Cutomer Name                                   Customer Address  \
# 0     CWRK009-00-0926  PASINAN KEC.SINGOJURUH Singojuruh Kab. Banyuwa...
# 1     CWRK009-00-0188  JL PB SUDIRMAN JAJAG Gambiran Kab. Banyuwangi ...
# 2     CWRK009-00-0765  JL JUANDA -PASAR LAMA JAJAG Gambiran Kab. Bany...
# 3     CWRK009-00-0258  DEPAN STADION JAJAG Gambiran Kab. Banyuwangi J...
# 4     CWRK009-00-0055   BANGOSERE   Bangorejo Kab. Banyuwangi Jawa Timur
# 5   WRK009-23-0000144  DS SIUR KROMBANG / SANEPOREJO SILIRAGUNG Silir...
# 6   WRK009-23-0000144  DS SIUR KROMBANG / SANEPOREJO SILIRAGUNG Silir...
# 7   WRK009-22-0000025  JL BHAYANGKARA KEBONREJO KEC BANGOREJO Bangore...
# 8   WRK009-21-0000020  DSN. KRAJANG SILIRAGUNG Siliragung Kab. Banyuw...
# 9   WRK009-21-0000020  DSN. KRAJANG SILIRAGUNG Siliragung Kab. Banyuw...
# 10  WRK009-21-0000020  DSN. KRAJANG SILIRAGUNG Siliragung Kab. Banyuw...
# 11    CWRK009-00-0801  JL RAYA KESILIR PESANGGRAHAN Siliragung Kab. B...
# ...

# %%
customer_names = [
    'WRK009-21-0000101', 'WRK009-22-0000029', 'CWRK009-00-0902', 'CWRK009-00-0109',
    'WRK009-21-0000069', 'WRK009-21-0000094', 'WRK009-22-0000036', 'WRK009-23-0000034',
    'WRK009-23-0000034', 'WRK009-21-0000053', 'CWRK009-00-0866', 'CWRK009-00-0517',
    'CWRK009-00-0517', 'CWRK009-00-0059', 'WRK009-21-0000002', 'CWRK009-00-0219',
    'CWRK009-00-0108', 'CWRK009-00-0906', 'WRK009-21-0000100', 'WRK009-22-0000014',
    'CWRK009-00-0177', 'CWRK009-00-0820', 'WRK009-21-0000081', 'WRK009-21-0000011',
    'CWRK009-00-0111', 'CWRK009-00-0148', 'WRK009-21-0000010', 'CWRK009-00-0159',
    'WRK009-23-0000031'
]

# Filter data berdasarkan Customer Name
filtered_df = df[df['Cutomer Name'].isin(customer_names)]

# Menggunakan iloc untuk menyusun data
df_w2v1 = filtered_df.copy()
df_w2v1.set_index('Cutomer Name', inplace=True)
df_w2v1 = df_w2v1.loc[customer_names].reset_index()
# Menyimpan hasil ke file baru
df_w2v1.to_excel('data\output\Filtered_df_w2v1.xlsx', index=False)
# Out:
# <>:20: SyntaxWarning: invalid escape sequence '\o'
# <>:20: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\muham\AppData\Local\Temp\ipykernel_10252\3970891757.py:20: SyntaxWarning: invalid escape sequence '\o'
#   df_w2v1.to_excel('data\output\Filtered_df_w2v1.xlsx', index=False)

# %%
df_w2v1
# Out:
#          Cutomer Name                                   Customer Address  \
# 0   WRK009-21-0000101  JL HOS COKROAMINOTO CUNGKING BWI Giri Kab. Ban...
# 1   WRK009-22-0000029  JL ARUJI KERTAWINATA DSN JURUH Singojuruh Kab....
# 2     CWRK009-00-0902  Singojuruh (BARAT KORAMIL SINGOJURUH) Singojur...
# 3     CWRK009-00-0109  JL RAYA GENDOH 144  Singojuruh Kab. Banyuwangi...
# 4   WRK009-21-0000069  JL TEMUGURUH TEMUASRI SEMPI Sempu Kab. Banyuwa...
# 5   WRK009-21-0000094  JL KALISTAIL SEMPU BANYUWANGI Sempu Kab. Banyu...
# 6   WRK009-22-0000036             SEMPU Sempu Kab. Banyuwangi Jawa Timur
# 7   WRK009-23-0000034  DS KARANGREJO NO 3 GLENMORE Glenmore Kab. Bany...
# 8   WRK009-23-0000034  DS KARANGREJO NO 3 GLENMORE Glenmore Kab. Bany...
# 9   WRK009-21-0000053  JL RAYA JEMBER GLENMORE Glenmore Kab. Banyuwan...
# 10    CWRK009-00-0866  Jl. KH. Wahid Hasyim No. 149 Genteng Kab. Bany...
# 11    CWRK009-00-0517  JL RAYA TEGALSARI Genteng Kab. Banyuwangi Jawa...
# ...

# %%
customer_names = [
    'WRK009-23-0000030', 'CWRK009-00-0082', 'WRK009-23-0000129', 'CWRK009-00-0125',
    'CWRK009-00-0762', 'CWRK009-00-0294', 'CWRK009-00-0514', 'CWRK009-00-0119',
    'WRK009-21-0000056', 'WRK009-20-0000058'
]

# Filter data berdasarkan Customer Name
filtered_df = df[df['Cutomer Name'].isin(customer_names)]

# Menggunakan iloc untuk menyusun data
df_w2v2 = filtered_df.copy()
df_w2v2.set_index('Cutomer Name', inplace=True)
df_w2v2 = df_w2v2.loc[customer_names].reset_index()
# Menyimpan hasil ke file baru
df_w2v2.to_excel('data\output\Filtered_df_w2v2.xlsx', index=False)
# Out:
# <>:15: SyntaxWarning: invalid escape sequence '\o'
# <>:15: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\muham\AppData\Local\Temp\ipykernel_10252\3685644791.py:15: SyntaxWarning: invalid escape sequence '\o'
#   df_w2v2.to_excel('data\output\Filtered_df_w2v2.xlsx', index=False)

# %%
df_w2v2
# Out:
#         Cutomer Name                                   Customer Address  \
# 0  WRK009-23-0000030  JL KOLONEL SUGIYONO NO 40 BANYUWANGI  Banyuwan...
# 1    CWRK009-00-0082  JL IKAN TOMBRO 28 Banyuwangi Kab. Banyuwangi J...
# 2  WRK009-23-0000129  TAMAN BLAMBANGAN BANYUWANGI Banyuwangi Kab. Ba...
# 3    CWRK009-00-0125  JL GATOT SUBROTO 175 Kalipuro Kab. Banyuwangi ...
# 4    CWRK009-00-0762  JL RAYA KETAPANG Banyuwangi Kab. Banyuwangi Ja...
# 5    CWRK009-00-0294  JL RAYA SITUBONDO Wongsorejo Kab. Banyuwangi J...
# 6    CWRK009-00-0514    JL SURABAYA Kalipuro Kab. Banyuwangi Jawa Timur
# 7    CWRK009-00-0119  JL BASUKI RAHMAT 56 Banyuwangi Kab. Banyuwangi...
# 8  WRK009-21-0000056  JL MH THAMRIN SINGOTRUNAN BANYUWANGI Banyuwang...
# 9  WRK009-20-0000058  JL PB SUDIRMAN BANYUWANGI Banyuwangi Kab. Bany...
#
#                      Customer Coordinate Open Time Close Time  Visit Tag  \
# 0                   -8.222706,114.372532  09:00:00   14:30:00        NaN
# ...

# %%
customer_names = [
    'CWRK009-00-0926', 'CWRK009-00-0542', 'WRK009-23-0000144', 'CWRK009-00-0214',
    'CWRK009-00-0258', 'CWRK009-00-0101', 'WRK009-21-0000064', 'CWRK009-00-0316',
    'CWRK009-00-0356', 'WRK009-21-0000063', 'CWRK009-00-0854', 'CWRK009-00-0163',
    'CWRK009-00-0227', 'CWRK009-00-0207', 'WRK009-20-0000033', 'CWRK009-00-0014',
    'WRK009-21-0000008'
]


# Filter data berdasarkan Customer Name
filtered_df = df[df['Cutomer Name'].isin(customer_names)]

# Menggunakan iloc untuk menyusun data
df_w2v3 = filtered_df.copy()
df_w2v3.set_index('Cutomer Name', inplace=True)
df_w2v3 = df_w2v3.loc[customer_names].reset_index()
# Menyimpan hasil ke file baru
df_w2v3.to_excel('data\output\Filtered_df_w2v3.xlsx', index=False)
# Out:
# <>:18: SyntaxWarning: invalid escape sequence '\o'
# <>:18: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\muham\AppData\Local\Temp\ipykernel_10252\3360615599.py:18: SyntaxWarning: invalid escape sequence '\o'
#   df_w2v3.to_excel('data\output\Filtered_df_w2v3.xlsx', index=False)

# %%
df_w2v3
# Out:
#          Cutomer Name                                   Customer Address  \
# 0     CWRK009-00-0926  PASINAN KEC.SINGOJURUH Singojuruh Kab. Banyuwa...
# 1     CWRK009-00-0542  JL RAYA TEGALSARI Genteng Kab. Banyuwangi Jawa...
# 2   WRK009-23-0000144  DS SIUR KROMBANG / SANEPOREJO SILIRAGUNG Silir...
# 3     CWRK009-00-0214  DPN POM BENSIN JAJAG RT7 RW 3 Gambiran Kab. Ba...
# 4     CWRK009-00-0258  DEPAN STADION JAJAG Gambiran Kab. Banyuwangi J...
# 5     CWRK009-00-0101  JL RAYA JAJAG 121 Gambiran Kab. Banyuwangi Jaw...
# 6   WRK009-21-0000064  JL RAYA CLURING DN KEPATIHAN  BANYUWANGI Cluri...
# 7     CWRK009-00-0316  JL RAYA BENCULUK Cluring Kab. Banyuwangi Jawa ...
# 8     CWRK009-00-0356  Dp. Lap simbar Purwoharjo Kab. Banyuwangi Jawa...
# 9   WRK009-21-0000063  JL RAYA JATIREJO DS GLAGAH AGUNG TEGALDLIMO Te...
# 10    CWRK009-00-0854  Depan SLB PGRI Tegal Dlimo Tegaldlimo Kab. Ban...
# 11    CWRK009-00-0163  PASAR SUMBER AYU Muncar Kab. Banyuwangi Jawa T...
# ...

# %%
customer_names = [
    'CWRK009-00-0122', 'CWRK009-00-0360', 'CWRK009-00-0416', 'CWRK009-00-0416',
    'CWRK009-00-0217', 'CWRK009-00-0832', 'CWRK009-00-0832', 'WRK009-23-0000104',
    'CWRK009-00-0710', 'CWRK009-00-0710', 'CWRK009-00-0867', 'CWRK009-00-0535',
    'WRK009-21-0000020', 'WRK009-21-0000020', 'WRK009-21-0000020', 'WRK009-21-0000020',
    'WRK009-22-0000090', 'WRK009-22-0000090', 'WRK009-22-0000090', 'WRK009-22-0000090',
    'WRK009-22-0000090', 'WRK009-22-0000090', 'CWRK009-00-0107', 'WRK009-23-0000139',
    'WRK009-23-0000139', 'CWRK009-00-0449'
]

# Filter data berdasarkan Customer Name
filtered_df = df[df['Cutomer Name'].isin(customer_names)]

# Menggunakan iloc untuk menyusun data
df_w2v4 = filtered_df.copy()
df_w2v4.set_index('Cutomer Name', inplace=True)
df_w2v4 = df_w2v4.loc[customer_names].reset_index()
# Menyimpan hasil ke file baru
df_w2v4.to_excel('data\output\Filtered_df_w2v4.xlsx', index=False)
# Out:
# <>:19: SyntaxWarning: invalid escape sequence '\o'
# <>:19: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\muham\AppData\Local\Temp\ipykernel_10252\3782565063.py:19: SyntaxWarning: invalid escape sequence '\o'
#   df_w2v4.to_excel('data\output\Filtered_df_w2v4.xlsx', index=False)

# %%
df_w2v4
# Out:
#          Cutomer Name                                   Customer Address  \
# 0     CWRK009-00-0122  JL BLIMBINGSARI TEGALREJO Rogojampi Kab. Banyu...
# 1     CWRK009-00-0360     TEMBOK REJO  Muncar Kab. Banyuwangi Jawa Timur
# 2     CWRK009-00-0416     JL SAMPANGAN Muncar Kab. Banyuwangi Jawa Timur
# 3     CWRK009-00-0416     JL SAMPANGAN Muncar Kab. Banyuwangi Jawa Timur
# 4     CWRK009-00-0217       JL PATEMON Muncar Kab. Banyuwangi Jawa Timur
# 5     CWRK009-00-0832  Selatan Puskesmas Sumber Beras Muncar Kab. Ban...
# 6     CWRK009-00-0832  Selatan Puskesmas Sumber Beras Muncar Kab. Ban...
# 7   WRK009-23-0000104  JL  BUBG KARNO TEGALDLIMO Tegaldlimo Kab. Bany...
# 8     CWRK009-00-0710  PASAR BENCULUK Cluring Kab. Banyuwangi Jawa Timur
# 9     CWRK009-00-0710  PASAR BENCULUK Cluring Kab. Banyuwangi Jawa Timur
# 10    CWRK009-00-0867  Jl. Raya Keradenan Purwoharjo Kab. Banyuwangi ...
# 11    CWRK009-00-0535  RUKO PEDOTAN   Bangorejo Kab. Banyuwangi Jawa ...
# ...

# %%
customer_names = [
    'CWRK009-00-0122', 'CWRK009-00-0360', 'CWRK009-00-0416', 'CWRK009-00-0416',
    'CWRK009-00-0217', 'CWRK009-00-0832', 'CWRK009-00-0832', 'WRK009-23-0000104',
    'CWRK009-00-0710', 'CWRK009-00-0710', 'CWRK009-00-0867', 'CWRK009-00-0535',
    'WRK009-21-0000020', 'WRK009-21-0000020', 'WRK009-21-0000020', 'WRK009-21-0000020',
    'WRK009-22-0000090', 'WRK009-22-0000090', 'WRK009-22-0000090', 'WRK009-22-0000090',
    'WRK009-22-0000090', 'WRK009-22-0000090', 'CWRK009-00-0107', 'WRK009-23-0000139',
    'WRK009-23-0000139', 'CWRK009-00-0449'
]

# Filter data berdasarkan Customer Name
filtered_df = df[df['Cutomer Name'].isin(customer_names)]

# Menggunakan iloc untuk menyusun data
df_w3v1 = filtered_df.copy()
df_w3v1.set_index('Cutomer Name', inplace=True)
df_w3v1 = df_w3v1.loc[customer_names].reset_index()
# Menyimpan hasil ke file baru
df_w3v1.to_excel('data\output\Filtered_df_w3v1.xlsx', index=False)
df_w3v1
# Out:
# <>:19: SyntaxWarning: invalid escape sequence '\o'
# <>:19: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\muham\AppData\Local\Temp\ipykernel_10252\1037343234.py:19: SyntaxWarning: invalid escape sequence '\o'
#   df_w3v1.to_excel('data\output\Filtered_df_w3v1.xlsx', index=False)
#          Cutomer Name                                   Customer Address  \
# 0     CWRK009-00-0122  JL BLIMBINGSARI TEGALREJO Rogojampi Kab. Banyu...
# 1     CWRK009-00-0360     TEMBOK REJO  Muncar Kab. Banyuwangi Jawa Timur
# 2     CWRK009-00-0416     JL SAMPANGAN Muncar Kab. Banyuwangi Jawa Timur
# 3     CWRK009-00-0416     JL SAMPANGAN Muncar Kab. Banyuwangi Jawa Timur
# 4     CWRK009-00-0217       JL PATEMON Muncar Kab. Banyuwangi Jawa Timur
# 5     CWRK009-00-0832  Selatan Puskesmas Sumber Beras Muncar Kab. Ban...
# 6     CWRK009-00-0832  Selatan Puskesmas Sumber Beras Muncar Kab. Ban...
# 7   WRK009-23-0000104  JL  BUBG KARNO TEGALDLIMO Tegaldlimo Kab. Bany...
# ...

# %%
customer_names = [
    'CWRK009-00-0143', 'CWRK009-00-0191', 'WRK009-23-0000074', 'WRK009-21-0000014',
    'WRK009-19-0000010', 'WRK009-19-0000009', 'WRK009-21-0000082', 'CWRK009-00-0533',
    'CWRK009-00-0343', 'CWRK009-00-0071', 'CWRK009-00-0267', 'CWRK009-00-0402',
    'CWRK009-00-0402', 'CWRK009-00-0854', 'CWRK009-00-0854', 'CWRK009-00-0867',
    'CWRK009-00-0909', 'WRK009-23-0000127', 'CWRK009-00-0137', 'WRK009-21-0000016',
    'CWRK009-00-0161', 'CWRK009-00-0258', 'WRK009-23-0000060', 'CWRK009-00-0542',
    'CWRK009-00-0168'
]


# Filter data berdasarkan Customer Name
filtered_df = df[df['Cutomer Name'].isin(customer_names)]

# Menggunakan iloc untuk menyusun data
df_w3v2 = filtered_df.copy()
df_w3v2.set_index('Cutomer Name', inplace=True)
df_w3v2 = df_w3v2.loc[customer_names].reset_index()
# Menyimpan hasil ke file baru
df_w3v2.to_excel('data\output\Filtered_df_w3v2.xlsx', index=False)
df_w3v2
# Out:
# <>:20: SyntaxWarning: invalid escape sequence '\o'
# <>:20: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\muham\AppData\Local\Temp\ipykernel_10252\2419115681.py:20: SyntaxWarning: invalid escape sequence '\o'
#   df_w3v2.to_excel('data\output\Filtered_df_w3v2.xlsx', index=False)
#          Cutomer Name                                   Customer Address  \
# 0     CWRK009-00-0143  DALAM PASAR ROGOJAMPI Rogojampi Kab. Banyuwang...
# 1     CWRK009-00-0191  JL RAYA ROGOJAMPI Rogojampi Kab. Banyuwangi Ja...
# 2   WRK009-23-0000074  JL BOLODEWO LEMAHBANGDEWO NO 17 ROGOJAMPI  Rog...
# 3   WRK009-21-0000014  KEBAMAN SRONO BANYUWANGI Srono Kab. Banyuwangi...
# 4   WRK009-19-0000010  JL SULTAN AGUNG NO 95 MUNCAR Muncar Kab. Banyu...
# 5   WRK009-19-0000009  JL RAYA SETINGGIL NO 35 MUNCAR Muncar Kab. Ban...
# 6   WRK009-21-0000082  JL BRAWIJAYA MUNCAR Muncar Kab. Banyuwangi Jaw...
# 7     CWRK009-00-0533    TERMINAL LAMA Muncar Kab. Banyuwangi Jawa Timur
# ...

# %%
customer_names = [
    'CWRK009-00-0421', 'WRK009-23-0000092', 'WRK009-20-0000051', 'CWRK009-00-0038',
    'WRK009-20-0000034', 'WRK009-20-0000034', 'CWRK009-00-0225', 'CWRK009-00-0485',
    'CWRK009-00-0127', 'CWRK009-00-0820', 'CWRK009-00-0187', 'CWRK009-00-0195',
    'CWRK009-00-0888', 'CWRK009-00-0241', 'CWRK009-00-0414', 'CWRK009-00-0414',
    'CWRK009-00-0180', 'CWRK009-00-0262', 'CWRK009-00-0893', 'WRK009-21-0000094',
    'WRK009-21-0000069', 'WRK009-23-0000093', 'WRK009-22-0000027'
]


# Filter data berdasarkan Customer Name
filtered_df = df[df['Cutomer Name'].isin(customer_names)]

# Menggunakan iloc untuk menyusun data
df_w3v3 = filtered_df.copy()
df_w3v3.set_index('Cutomer Name', inplace=True)
df_w3v3 = df_w3v3.loc[customer_names].reset_index()
# Menyimpan hasil ke file baru
df_w3v3.to_excel('data\output\Filtered_df_w3v3.xlsx', index=False)
df_w3v3
# Out:
# <>:19: SyntaxWarning: invalid escape sequence '\o'
# <>:19: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\muham\AppData\Local\Temp\ipykernel_10252\1769864654.py:19: SyntaxWarning: invalid escape sequence '\o'
#   df_w3v3.to_excel('data\output\Filtered_df_w3v3.xlsx', index=False)
#          Cutomer Name                                   Customer Address  \
# 0     CWRK009-00-0421  JL. A YANI PENGAJUARAN BLOCK NO 21-23 Banyuwan...
# 1   WRK009-23-0000092  JL MENDUT 24 BANYUWANGI Banyuwangi Kab. Banyuw...
# 2   WRK009-20-0000051  JL KEPITING BANYUWANGI Banyuwangi Kab. Banyuwa...
# 3     CWRK009-00-0038  JL S PARMAN NO 7A Banyuwangi Kab. Banyuwangi J...
# 4   WRK009-20-0000034  JL RAYA JEMBER NO 111 UTARA MASJID DADAPAN BAN...
# 5   WRK009-20-0000034  JL RAYA JEMBER NO 111 UTARA MASJID DADAPAN BAN...
# 6     CWRK009-00-0225         BANGOREJO Srono Kab. Banyuwangi Jawa Timur
# 7     CWRK009-00-0485   PASAR BANGOREJO Srono Kab. Banyuwangi Jawa Timur
# ...

# %%
customer_names = [
    'CWRK009-00-0034', 'CWRK009-00-0022', 'WRK009-19-0000018', 'CWRK009-00-0110',
    'CWRK009-00-0010', 'WRK009-22-0000047', 'WRK009-22-0000047', 'CWRK009-00-0762',
    'WRK009-21-0000025', 'CWRK009-00-0775', 'CWRK009-00-0775', 'WRK009-19-0000003',
    'CWRK009-00-0079', 'WRK009-21-0000095', 'CWRK009-00-0181', 'WRK009-20-0000058',
    'CWRK009-00-0155'
]

# Filter data berdasarkan Customer Name
filtered_df = df[df['Cutomer Name'].isin(customer_names)]

# Menggunakan iloc untuk menyusun data
df_w3v4 = filtered_df.copy()
df_w3v4.set_index('Cutomer Name', inplace=True)
df_w3v4 = df_w3v4.loc[customer_names].reset_index()
# Menyimpan hasil ke file baru
df_w3v4.to_excel('data\output\Filtered_df_w3v4.xlsx', index=False)
df_w3v4
# Out:
# <>:17: SyntaxWarning: invalid escape sequence '\o'
# <>:17: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\muham\AppData\Local\Temp\ipykernel_10252\2310188975.py:17: SyntaxWarning: invalid escape sequence '\o'
#   df_w3v4.to_excel('data\output\Filtered_df_w3v4.xlsx', index=False)
#          Cutomer Name                                   Customer Address  \
# 0     CWRK009-00-0034  JL A YANI NO 10 Banyuwangi Kab. Banyuwangi Jaw...
# 1     CWRK009-00-0022  JL MH THAMRIN 26 Banyuwangi Kab. Banyuwangi Ja...
# 2   WRK009-19-0000018  PULAU SANTEN KARANGREJO BANYUWANGI Banyuwangi ...
# 3     CWRK009-00-0110  JL SAYUWIWIT 1 GANG JAKA TA Banyuwangi Kab. Ba...
# 4     CWRK009-00-0010  JL SAYUWIWIT 38 Banyuwangi Kab. Banyuwangi Jaw...
# 5   WRK009-22-0000047  JL BASUKI RAHMAT BANYUWANGI Banyuwangi Kab. Ba...
# 6   WRK009-22-0000047  JL BASUKI RAHMAT BANYUWANGI Banyuwangi Kab. Ba...
# 7     CWRK009-00-0762  JL RAYA KETAPANG Banyuwangi Kab. Banyuwangi Ja...
# ...

# %%
customer_names = [
    'CWRK009-00-0033', 'CWRK009-00-0110', 'CWRK009-00-0010', 'WRK009-22-0000045',
    'WRK009-22-0000045', 'CWRK009-00-0023', 'CWRK009-00-0775', 'WRK009-21-0000025',
    'CWRK009-00-0762', 'CWRK009-00-0514', 'WRK009-21-0000103', 'CWRK009-00-0370',
    'CWRK009-00-0193', 'WRK009-19-0000018', 'CWRK009-00-0082', 'CWRK009-00-0041',
    'CWRK009-00-0034'
]

# Filter data berdasarkan Customer Name
filtered_df = df[df['Cutomer Name'].isin(customer_names)]

# Menggunakan iloc untuk menyusun data
df_w4v1 = filtered_df.copy()
df_w4v1.set_index('Cutomer Name', inplace=True)
df_w4v1 = df_w4v1.loc[customer_names].reset_index()
# Menyimpan hasil ke file baru
df_w4v1.to_excel('data\output\Filtered_df_w4v1.xlsx', index=False)
df_w4v1
# Out:
# <>:17: SyntaxWarning: invalid escape sequence '\o'
# <>:17: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\muham\AppData\Local\Temp\ipykernel_10252\1728927530.py:17: SyntaxWarning: invalid escape sequence '\o'
#   df_w4v1.to_excel('data\output\Filtered_df_w4v1.xlsx', index=False)
#          Cutomer Name                                   Customer Address  \
# 0     CWRK009-00-0033  DALAM PASAR NO 61 Banyuwangi Kab. Banyuwangi J...
# 1     CWRK009-00-0110  JL SAYUWIWIT 1 GANG JAKA TA Banyuwangi Kab. Ba...
# 2     CWRK009-00-0010  JL SAYUWIWIT 38 Banyuwangi Kab. Banyuwangi Jaw...
# 3   WRK009-22-0000045  JL BASUKI RAHMAT BANYUWANGI Banyuwangi Kab. Ba...
# 4   WRK009-22-0000045  JL BASUKI RAHMAT BANYUWANGI Banyuwangi Kab. Ba...
# 5     CWRK009-00-0023  JL RAYA SITUBONDO  Wongsorejo Kab. Banyuwangi ...
# 6     CWRK009-00-0775  JL RAYA GALEKAN WONGSOREJO Wongsorejo Kab. Ban...
# 7   WRK009-21-0000025   WONGSOREJO Banyuwangi Kab. Banyuwangi Jawa Timur
# ...

# %%
customer_names = [
    'CWRK009-00-0136', 'CWRK009-00-0618', 'CWRK009-00-0111', 'CWRK009-00-0143',
    'WRK009-21-0000010', 'WRK009-21-0000011', 'WRK009-21-0000072', 'CWRK009-00-0364',
    'CWRK009-00-0144', 'WRK009-21-0000013', 'WRK009-21-0000013', 'CWRK009-00-0018',
    'CWRK009-00-0194', 'WRK009-21-0000064', 'CWRK009-00-0316', 'CWRK009-00-0356',
    'CWRK009-00-0407', 'WRK009-19-0000013', 'CWRK009-00-0278', 'CWRK009-00-0464',
    'WRK009-20-0000036', 'WRK009-21-0000115', 'WRK009-21-0000082', 'CWRK009-00-0291',
    'WRK009-20-0000052'
]

# Filter data berdasarkan Customer Name
filtered_df = df[df['Cutomer Name'].isin(customer_names)]

# Menggunakan iloc untuk menyusun data
df_w4v2 = filtered_df.copy()
df_w4v2.set_index('Cutomer Name', inplace=True)
df_w4v2 = df_w4v2.loc[customer_names].reset_index()
# Menyimpan hasil ke file baru
df_w4v2.to_excel('data\output\Filtered_df_w4v2.xlsx', index=False)
df_w4v2
# Out:
# <>:19: SyntaxWarning: invalid escape sequence '\o'
# <>:19: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\muham\AppData\Local\Temp\ipykernel_10252\1208561550.py:19: SyntaxWarning: invalid escape sequence '\o'
#   df_w4v2.to_excel('data\output\Filtered_df_w4v2.xlsx', index=False)
#          Cutomer Name                                   Customer Address  \
# 0     CWRK009-00-0136    JL BRAWIJAYA 31 Giri Kab. Banyuwangi Jawa Timur
# 1     CWRK009-00-0618       BENELAN LOR Kabat Kab. Banyuwangi Jawa Timur
# 2     CWRK009-00-0111  JL RAYA ROGOJAMPI Rogojampi Kab. Banyuwangi Ja...
# 3     CWRK009-00-0143  DALAM PASAR ROGOJAMPI Rogojampi Kab. Banyuwang...
# 4   WRK009-21-0000010  JL RAYA JEMBER DEPAN MASJID JAMI ROGOJAMPI BAN...
# 5   WRK009-21-0000011  DPN MASJID LUGONTO ROGOJAMPI Rogojampi Kab. Ba...
# 6   WRK009-21-0000072  JL RAYA GLADAG BANJE Rogojampi Kab. Banyuwangi...
# 7     CWRK009-00-0364  JL RAYA SRONO WONOSOBO Srono Kab. Banyuwangi J...
# ...

# %%
customer_names = [
    'WRK009-23-0000030', 'WRK009-23-0000141', 'CWRK009-00-0483', 'CWRK009-00-0171',
    'WRK009-19-0000010', 'WRK009-20-0000036', 'CWRK009-00-0326', 'CWRK009-00-0884',
    'CWRK009-00-0884', 'CWRK009-00-0884', 'CWRK009-00-0884', 'CWRK009-00-0854',
    'CWRK009-00-0854', 'CWRK009-00-0844', 'CWRK009-00-0909', 'CWRK009-00-0823',
    'WRK009-20-0000064', 'CWRK009-00-0055', 'CWRK009-00-0214', 'CWRK009-00-0347',
    'WRK009-22-0000024', 'WRK009-21-0000054'
]

# Filter data berdasarkan Customer Name
filtered_df = df[df['Cutomer Name'].isin(customer_names)]

# Menggunakan iloc untuk menyusun data
df_w4v3 = filtered_df.copy()
df_w4v3.set_index('Cutomer Name', inplace=True)
df_w4v3 = df_w4v3.loc[customer_names].reset_index()
# Menyimpan hasil ke file baru
df_w4v3.to_excel('data\output\Filtered_df_w4v3.xlsx', index=False)
df_w4v3
# Out:
# <>:18: SyntaxWarning: invalid escape sequence '\o'
# <>:18: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\muham\AppData\Local\Temp\ipykernel_10252\1686635751.py:18: SyntaxWarning: invalid escape sequence '\o'
#   df_w4v3.to_excel('data\output\Filtered_df_w4v3.xlsx', index=False)
#          Cutomer Name                                   Customer Address  \
# 0   WRK009-23-0000030  JL KOLONEL SUGIYONO NO 40 BANYUWANGI  Banyuwan...
# 1   WRK009-23-0000141  PAKIS BANYUWANGI Banyuwangi Kab. Banyuwangi Ja...
# 2     CWRK009-00-0483      SUMBER SEWU Muncar Kab. Banyuwangi Jawa Timur
# 3     CWRK009-00-0171  Limbul Rejo, Bagorejo, Kec. Srono, Kabupaten B...
# 4   WRK009-19-0000010  JL SULTAN AGUNG NO 95 MUNCAR Muncar Kab. Banyu...
# 5   WRK009-20-0000036  STAN PASAR KAMIS BAGOREJO Srono Kab. Banyuwang...
# 6     CWRK009-00-0326         BANGOREJO Srono Kab. Banyuwangi Jawa Timur
# 7     CWRK009-00-0884  Dam Buntung Kec. Tegal Dlimo Tegaldlimo Kab. B...
# ...

# %%
customer_names = [
    'CWRK009-00-0065', 'WRK009-22-0000013', 'CWRK009-00-0893', 'CWRK009-00-0086',
    'CWRK009-00-0174', 'WRK009-23-0000034', 'WRK009-23-0000034', 'WRK009-23-0000034',
    'WRK009-21-0000075', 'WRK009-21-0000075', 'WRK009-21-0000075', 'WRK009-21-0000075',
    'CWRK009-00-0282', 'CWRK009-00-0107', 'CWRK009-00-0219', 'CWRK009-00-0120',
    'WRK009-21-0000071'
]

# Filter data berdasarkan Customer Name
filtered_df = df[df['Cutomer Name'].isin(customer_names)]

# Menggunakan iloc untuk menyusun data
df_w4v4 = filtered_df.copy()
df_w4v4.set_index('Cutomer Name', inplace=True)
df_w4v4 = df_w4v4.loc[customer_names].reset_index()
# Menyimpan hasil ke file baru
df_w4v4.to_excel('data\output\Filtered_df_w4v4.xlsx', index=False)
df_w4v4
# Out:
# <>:17: SyntaxWarning: invalid escape sequence '\o'
# <>:17: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\muham\AppData\Local\Temp\ipykernel_10252\653503426.py:17: SyntaxWarning: invalid escape sequence '\o'
#   df_w4v4.to_excel('data\output\Filtered_df_w4v4.xlsx', index=False)
#          Cutomer Name                                   Customer Address  \
# 0     CWRK009-00-0065       KEMIRI Singojuruh Kab. Banyuwangi Jawa Timur
# 1   WRK009-22-0000013            GENDOH Sempu Kab. Banyuwangi Jawa Timur
# 2     CWRK009-00-0893  JL KALI STAIL NO 308 PS SEMPU Sempu Kab. Banyu...
# 3     CWRK009-00-0086     JL KALI STAIL Sempu Kab. Banyuwangi Jawa Timur
# 4     CWRK009-00-0174  DSN SELOREJO DSN KALIGONDO Singojuruh Kab. Ban...
# 5   WRK009-23-0000034  DS KARANGREJO NO 3 GLENMORE Glenmore Kab. Bany...
# 6   WRK009-23-0000034  DS KARANGREJO NO 3 GLENMORE Glenmore Kab. Bany...
# 7   WRK009-23-0000034  DS KARANGREJO NO 3 GLENMORE Glenmore Kab. Bany...
# ...
